# %%
# Import the dependencies and libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime
import requests
import time
from scipy.stats import linregress
import gmaps
#Import API keys
from config import g_key
from config import weather_api_key

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
lats = np.random.uniform(-90.00, 90.00, size = 2000)
lngs = np.random.uniform(-180.00, 180.00, size = 2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# Add coordinates to a list 
coordinates = list(lats_lngs)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
# Count amount of unique cities
len(cities)
# Out:
# 737

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
        # Parse the JSON data
        city_weather = requests.get(city_url).json()
        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | burnie
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | tokur
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | necochea
# Processing Record 9 of Set 1 | skjervoy
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | tasiilaq
# Processing Record 14 of Set 1 | karratha
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | acari
# Processing Record 17 of Set 1 | saint anthony
# Processing Record 18 of Set 1 | wyndham
# Processing Record 19 of Set 1 | truth or consequences
# Processing Record 20 of Set 1 | maceio
# Processing Record 21 of Set 1 | lagoa
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | saint-joseph
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | port hardy
# Processing Record 26 of Set 1 | nortelandia
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | sandwick
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | srandakan
# Processing Record 33 of Set 1 | banda aceh
# Processing Record 34 of Set 1 | mayo
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | tagusao
# Processing Record 38 of Set 1 | nurota
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | byron bay
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | batagay-alyta
# Processing Record 46 of Set 1 | voznesenskoye
# Processing Record 47 of Set 1 | mount isa
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | yar-sale
# Processing Record 50 of Set 1 | port macquarie
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | igarka
# Processing Record 3 of Set 2 | mahaicony
# City not found. Skipping
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | yirol
# City not found. Skipping
# Processing Record 6 of Set 2 | godda
# Processing Record 7 of Set 2 | comodoro rivadavia
# Processing Record 8 of Set 2 | la asuncion
# Processing Record 9 of Set 2 | saldanha
# Processing Record 10 of Set 2 | tres arroyos
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | dauphin
# Processing Record 13 of Set 2 | kawalu
# Processing Record 14 of Set 2 | norman wells
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping
# Processing Record 18 of Set 2 | hofn
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | manggar
# Processing Record 21 of Set 2 | umm kaddadah
# Processing Record 22 of Set 2 | plaridel
# Processing Record 23 of Set 2 | krasnogvardeyskiy
# Processing Record 24 of Set 2 | umm ruwabah
# City not found. Skipping
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 26 of Set 2 | zyryanovsk
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | rabo de peixe
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping
# Processing Record 30 of Set 2 | vilyuysk
# Processing Record 31 of Set 2 | sept-iles
# Processing Record 32 of Set 2 | ishigaki
# Processing Record 33 of Set 2 | srednekolymsk
# Processing Record 34 of Set 2 | djibo
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | seoul
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping
# Processing Record 38 of Set 2 | tanda
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | buala
# Processing Record 41 of Set 2 | ambodifototra
# City not found. Skipping
# Processing Record 42 of Set 2 | walvis bay
# Processing Record 43 of Set 2 | berlevag
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | vostok
# Processing Record 48 of Set 2 | cherskiy
# Processing Record 49 of Set 2 | matagami
# Processing Record 50 of Set 2 | faanui
# Processing Record 1 of Set 3 | scarborough
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | mogadouro
# Processing Record 4 of Set 3 | kota bahru
# Processing Record 5 of Set 3 | donskoye
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | san patricio
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | east london
# Processing Record 12 of Set 3 | the valley
# Processing Record 13 of Set 3 | anapolis
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | hornepayne
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping
# Processing Record 17 of Set 3 | nantucket
# Processing Record 18 of Set 3 | aykhal
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | gat
# Processing Record 22 of Set 3 | antalaha
# Processing Record 23 of Set 3 | egvekinot
# Processing Record 24 of Set 3 | lata
# Processing Record 25 of Set 3 | klaksvik
# Processing Record 26 of Set 3 | gasa
# Processing Record 27 of Set 3 | hami
# Processing Record 28 of Set 3 | port moresby
# Processing Record 29 of Set 3 | amahai
# Processing Record 30 of Set 3 | ostrovnoy
# Processing Record 31 of Set 3 | ayer itam
# City not found. Skipping
# Processing Record 32 of Set 3 | sentyabrskiy
# City not found. Skipping
# Processing Record 33 of Set 3 | flin flon
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | palora
# Processing Record 38 of Set 3 | woodward
# Processing Record 39 of Set 3 | filadelfia
# Processing Record 40 of Set 3 | richards bay
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | hambantota
# Processing Record 44 of Set 3 | san-pedro
# Processing Record 45 of Set 3 | broome
# Processing Record 46 of Set 3 | hilo
# Processing Record 47 of Set 3 | sinjah
# City not found. Skipping
# Processing Record 48 of Set 3 | marechal candido rondon
# Processing Record 49 of Set 3 | fairbanks
# Processing Record 50 of Set 3 | grindavik
# Processing Record 1 of Set 4 | puerto ayora
# Processing Record 2 of Set 4 | port shepstone
# Processing Record 3 of Set 4 | bay roberts
# Processing Record 4 of Set 4 | hualmay
# Processing Record 5 of Set 4 | ust-nera
# Processing Record 6 of Set 4 | trincomalee
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | meulaboh
# Processing Record 9 of Set 4 | vestmannaeyjar
# Processing Record 10 of Set 4 | oyama
# Processing Record 11 of Set 4 | geraldton
# Processing Record 12 of Set 4 | nicoya
# Processing Record 13 of Set 4 | dunedin
# Processing Record 14 of Set 4 | magole
# Processing Record 15 of Set 4 | dingle
# Processing Record 16 of Set 4 | portland
# Processing Record 17 of Set 4 | sumenep
# Processing Record 18 of Set 4 | kiama
# Processing Record 19 of Set 4 | alofi
# Processing Record 20 of Set 4 | ugoofaaru
# Processing Record 21 of Set 4 | tezu
# Processing Record 22 of Set 4 | ahipara
# Processing Record 23 of Set 4 | tura
# Processing Record 24 of Set 4 | nyurba
# Processing Record 25 of Set 4 | nikolayevsk-na-amure
# Processing Record 26 of Set 4 | amderma
# City not found. Skipping
# Processing Record 27 of Set 4 | barrow
# Processing Record 28 of Set 4 | batagay
# Processing Record 29 of Set 4 | methven
# Processing Record 30 of Set 4 | dalbandin
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | blantyre
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | tall kayf
# Processing Record 35 of Set 4 | presidente medici
# Processing Record 36 of Set 4 | vammala
# Processing Record 37 of Set 4 | shizunai
# Processing Record 38 of Set 4 | rafaela
# Processing Record 39 of Set 4 | conceicao do almeida
# Processing Record 40 of Set 4 | cardston
# Processing Record 41 of Set 4 | barentsburg
# City not found. Skipping
# Processing Record 42 of Set 4 | dustlik
# Processing Record 43 of Set 4 | canakkale
# Processing Record 44 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 4 | brae
# Processing Record 46 of Set 4 | alappuzha
# Processing Record 47 of Set 4 | fort saint james
# Processing Record 48 of Set 4 | zhigansk
# Processing Record 49 of Set 4 | tabialan
# City not found. Skipping
# Processing Record 50 of Set 4 | cap malheureux
# Processing Record 1 of Set 5 | nhulunbuy
# Processing Record 2 of Set 5 | marsh harbour
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | voh
# Processing Record 5 of Set 5 | bacuit
# City not found. Skipping
# Processing Record 6 of Set 5 | longyearbyen
# Processing Record 7 of Set 5 | opuwo
# Processing Record 8 of Set 5 | kahului
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | levokumskoye
# Processing Record 11 of Set 5 | maragogi
# Processing Record 12 of Set 5 | clyde river
# Processing Record 13 of Set 5 | wajima
# Processing Record 14 of Set 5 | boguchany
# Processing Record 15 of Set 5 | dipkarpaz
# City not found. Skipping
# Processing Record 16 of Set 5 | lichtenburg
# Processing Record 17 of Set 5 | saleaula
# City not found. Skipping
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | tabriz
# Processing Record 20 of Set 5 | port hedland
# Processing Record 21 of Set 5 | kirakira
# Processing Record 22 of Set 5 | luderitz
# Processing Record 23 of Set 5 | kenai
# Processing Record 24 of Set 5 | buraydah
# Processing Record 25 of Set 5 | port blair
# Processing Record 26 of Set 5 | mokrous
# Processing Record 27 of Set 5 | tiksi
# Processing Record 28 of Set 5 | williston
# Processing Record 29 of Set 5 | waddan
# Processing Record 30 of Set 5 | evanston
# Processing Record 31 of Set 5 | attawapiskat
# City not found. Skipping
# Processing Record 32 of Set 5 | luxor
# Processing Record 33 of Set 5 | macherla
# Processing Record 34 of Set 5 | bengkulu
# Processing Record 35 of Set 5 | tawkar
# City not found. Skipping
# Processing Record 36 of Set 5 | alihe
# Processing Record 37 of Set 5 | esperance
# Processing Record 38 of Set 5 | gizo
# Processing Record 39 of Set 5 | tra vinh
# Processing Record 40 of Set 5 | cravo norte
# Processing Record 41 of Set 5 | vitina
# Processing Record 42 of Set 5 | castro
# Processing Record 43 of Set 5 | palabuhanratu
# City not found. Skipping
# Processing Record 44 of Set 5 | saint george
# Processing Record 45 of Set 5 | davila
# Processing Record 46 of Set 5 | barcelos
# Processing Record 47 of Set 5 | wagga wagga
# Processing Record 48 of Set 5 | bilibino
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | praia da vitoria
# Processing Record 1 of Set 6 | honningsvag
# Processing Record 2 of Set 6 | dikson
# Processing Record 3 of Set 6 | puksoozero
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | aflu
# City not found. Skipping
# Processing Record 6 of Set 6 | pemba
# Processing Record 7 of Set 6 | dutlwe
# Processing Record 8 of Set 6 | dolbeau
# City not found. Skipping
# Processing Record 9 of Set 6 | kaitangata
# Processing Record 10 of Set 6 | chalus
# Processing Record 11 of Set 6 | winneba
# Processing Record 12 of Set 6 | saint-denis
# Processing Record 13 of Set 6 | beloha
# Processing Record 14 of Set 6 | vila velha
# Processing Record 15 of Set 6 | herat
# Processing Record 16 of Set 6 | dhidhdhoo
# Processing Record 17 of Set 6 | harper
# Processing Record 18 of Set 6 | shingu
# Processing Record 19 of Set 6 | flinders
# Processing Record 20 of Set 6 | launceston
# Processing Record 21 of Set 6 | neuquen
# Processing Record 22 of Set 6 | shihezi
# Processing Record 23 of Set 6 | ovsyanka
# Processing Record 24 of Set 6 | chalons-en-champagne
# Processing Record 25 of Set 6 | chagda
# City not found. Skipping
# Processing Record 26 of Set 6 | oranjestad
# Processing Record 27 of Set 6 | booue
# Processing Record 28 of Set 6 | banjar
# Processing Record 29 of Set 6 | youkounkoun
# Processing Record 30 of Set 6 | halalo
# City not found. Skipping
# Processing Record 31 of Set 6 | toliary
# City not found. Skipping
# Processing Record 32 of Set 6 | felidhoo
# City not found. Skipping
# Processing Record 33 of Set 6 | bereda
# Processing Record 34 of Set 6 | qui nhon
# Processing Record 35 of Set 6 | riyadh
# Processing Record 36 of Set 6 | georgiyevskoye
# Processing Record 37 of Set 6 | yulara
# Processing Record 38 of Set 6 | hasaki
# Processing Record 39 of Set 6 | george
# Processing Record 40 of Set 6 | asau
# Processing Record 41 of Set 6 | belaya gora
# Processing Record 42 of Set 6 | margate
# Processing Record 43 of Set 6 | narsaq
# Processing Record 44 of Set 6 | itoman
# Processing Record 45 of Set 6 | binzhou
# Processing Record 46 of Set 6 | chunskiy
# Processing Record 47 of Set 6 | skagastrond
# City not found. Skipping
# Processing Record 48 of Set 6 | villiers
# Processing Record 49 of Set 6 | nikolskoye
# Processing Record 50 of Set 6 | rochester
# Processing Record 1 of Set 7 | saint-augustin
# Processing Record 2 of Set 7 | grand gaube
# Processing Record 3 of Set 7 | hickory
# Processing Record 4 of Set 7 | mandalgovi
# Processing Record 5 of Set 7 | malanje
# Processing Record 6 of Set 7 | lompoc
# Processing Record 7 of Set 7 | vardo
# Processing Record 8 of Set 7 | los llanos de aridane
# Processing Record 9 of Set 7 | nome
# Processing Record 10 of Set 7 | mobaye
# Processing Record 11 of Set 7 | pitimbu
# Processing Record 12 of Set 7 | batemans bay
# Processing Record 13 of Set 7 | san policarpo
# Processing Record 14 of Set 7 | udachnyy
# Processing Record 15 of Set 7 | moron
# Processing Record 16 of Set 7 | dolzhanskaya
# Processing Record 17 of Set 7 | fairlie
# Processing Record 18 of Set 7 | yeletskiy
# City not found. Skipping
# Processing Record 19 of Set 7 | isla mujeres
# Processing Record 20 of Set 7 | souillac
# Processing Record 21 of Set 7 | salinas
# Processing Record 22 of Set 7 | pocone
# Processing Record 23 of Set 7 | arraial do cabo
# Processing Record 24 of Set 7 | umzimvubu
# City not found. Skipping
# Processing Record 25 of Set 7 | kavieng
# Processing Record 26 of Set 7 | sur
# Processing Record 27 of Set 7 | jiblah
# Processing Record 28 of Set 7 | mandurah
# Processing Record 29 of Set 7 | atikokan
# Processing Record 30 of Set 7 | guerrero negro
# Processing Record 31 of Set 7 | iqaluit
# Processing Record 32 of Set 7 | tidore
# City not found. Skipping
# Processing Record 33 of Set 7 | mollendo
# Processing Record 34 of Set 7 | rovaniemi
# Processing Record 35 of Set 7 | kaeo
# Processing Record 36 of Set 7 | shenjiamen
# Processing Record 37 of Set 7 | sergeyevka
# Processing Record 38 of Set 7 | lasa
# Processing Record 39 of Set 7 | torbay
# Processing Record 40 of Set 7 | saint-georges
# Processing Record 41 of Set 7 | naze
# Processing Record 42 of Set 7 | saint-pierre
# Processing Record 43 of Set 7 | samusu
# City not found. Skipping
# Processing Record 44 of Set 7 | sola
# Processing Record 45 of Set 7 | mae hong son
# Processing Record 46 of Set 7 | avera
# Processing Record 47 of Set 7 | airai
# Processing Record 48 of Set 7 | andros town
# Processing Record 49 of Set 7 | araceli
# Processing Record 50 of Set 7 | zhezkazgan
# Processing Record 1 of Set 8 | sidareja
# Processing Record 2 of Set 8 | churapcha
# Processing Record 3 of Set 8 | sungaipenuh
# Processing Record 4 of Set 8 | komsomolskiy
# Processing Record 5 of Set 8 | garowe
# Processing Record 6 of Set 8 | orapa
# Processing Record 7 of Set 8 | faya
# Processing Record 8 of Set 8 | satitoa
# City not found. Skipping
# Processing Record 9 of Set 8 | bonavista
# Processing Record 10 of Set 8 | wahran
# City not found. Skipping
# Processing Record 11 of Set 8 | jalu
# Processing Record 12 of Set 8 | villarrica
# Processing Record 13 of Set 8 | kelvington
# Processing Record 14 of Set 8 | te anau
# Processing Record 15 of Set 8 | ewa beach
# Processing Record 16 of Set 8 | tsumeb
# Processing Record 17 of Set 8 | atar
# Processing Record 18 of Set 8 | macaboboni
# City not found. Skipping
# Processing Record 19 of Set 8 | murwara
# Processing Record 20 of Set 8 | zimmi
# Processing Record 21 of Set 8 | kuching
# Processing Record 22 of Set 8 | isangel
# Processing Record 23 of Set 8 | torrevieja
# Processing Record 24 of Set 8 | rock springs
# Processing Record 25 of Set 8 | marystown
# Processing Record 26 of Set 8 | boundiali
# Processing Record 27 of Set 8 | biak
# Processing Record 28 of Set 8 | koulikoro
# Processing Record 29 of Set 8 | alekseyevka
# Processing Record 30 of Set 8 | muli
# Processing Record 31 of Set 8 | manokwari
# Processing Record 32 of Set 8 | veraval
# Processing Record 33 of Set 8 | novikovo
# Processing Record 34 of Set 8 | trairi
# Processing Record 35 of Set 8 | saint-francois
# Processing Record 36 of Set 8 | clarence town
# Processing Record 37 of Set 8 | saurimo
# Processing Record 38 of Set 8 | meadow lake
# Processing Record 39 of Set 8 | keskin
# Processing Record 40 of Set 8 | hirara
# Processing Record 41 of Set 8 | sitka
# Processing Record 42 of Set 8 | voloshka
# Processing Record 43 of Set 8 | karakendzha
# City not found. Skipping
# Processing Record 44 of Set 8 | bathsheba
# Processing Record 45 of Set 8 | campobello di licata
# Processing Record 46 of Set 8 | bargal
# City not found. Skipping
# Processing Record 47 of Set 8 | san carlos de bariloche
# Processing Record 48 of Set 8 | tecoanapa
# Processing Record 49 of Set 8 | rapid valley
# Processing Record 50 of Set 8 | inhambane
# Processing Record 1 of Set 9 | kazerun
# Processing Record 2 of Set 9 | san jeronimo
# Processing Record 3 of Set 9 | maldonado
# Processing Record 4 of Set 9 | pisco
# Processing Record 5 of Set 9 | shanghai
# Processing Record 6 of Set 9 | touros
# Processing Record 7 of Set 9 | tulun
# Processing Record 8 of Set 9 | mangrol
# Processing Record 9 of Set 9 | izumo
# Processing Record 10 of Set 9 | togur
# Processing Record 11 of Set 9 | fortuna
# Processing Record 12 of Set 9 | vanavara
# Processing Record 13 of Set 9 | adrar
# Processing Record 14 of Set 9 | namibe
# Processing Record 15 of Set 9 | kapit
# Processing Record 16 of Set 9 | vrangel
# Processing Record 17 of Set 9 | mwinilunga
# Processing Record 18 of Set 9 | timon
# Processing Record 19 of Set 9 | lavrentiya
# Processing Record 20 of Set 9 | bela
# Processing Record 21 of Set 9 | sorong
# Processing Record 22 of Set 9 | khorixas
# Processing Record 23 of Set 9 | sarrebourg
# Processing Record 24 of Set 9 | moyale
# Processing Record 25 of Set 9 | nouakchott
# Processing Record 26 of Set 9 | omboue
# Processing Record 27 of Set 9 | bulgan
# Processing Record 28 of Set 9 | alice springs
# Processing Record 29 of Set 9 | quilmana
# Processing Record 30 of Set 9 | palmas bellas
# Processing Record 31 of Set 9 | bowling green
# Processing Record 32 of Set 9 | henties bay
# Processing Record 33 of Set 9 | calabozo
# Processing Record 34 of Set 9 | xuddur
# Processing Record 35 of Set 9 | inongo
# Processing Record 36 of Set 9 | teya
# Processing Record 37 of Set 9 | la orilla
# Processing Record 38 of Set 9 | crab hill
# City not found. Skipping
# Processing Record 39 of Set 9 | sao luis de montes belos
# Processing Record 40 of Set 9 | torata
# Processing Record 41 of Set 9 | onguday
# Processing Record 42 of Set 9 | yeppoon
# Processing Record 43 of Set 9 | llaillay
# Processing Record 44 of Set 9 | antanifotsy
# Processing Record 45 of Set 9 | eyl
# Processing Record 46 of Set 9 | sondershausen
# Processing Record 47 of Set 9 | piacabucu
# Processing Record 48 of Set 9 | itarema
# Processing Record 49 of Set 9 | kampot
# Processing Record 50 of Set 9 | bernal
# Processing Record 1 of Set 10 | chornobay
# Processing Record 2 of Set 10 | sal rei
# Processing Record 3 of Set 10 | taunggyi
# Processing Record 4 of Set 10 | kruisfontein
# Processing Record 5 of Set 10 | luanda
# Processing Record 6 of Set 10 | gurgan
# City not found. Skipping
# Processing Record 7 of Set 10 | qasigiannguit
# Processing Record 8 of Set 10 | katsuura
# Processing Record 9 of Set 10 | algete
# Processing Record 10 of Set 10 | bilma
# Processing Record 11 of Set 10 | las vegas
# Processing Record 12 of Set 10 | malakal
# Processing Record 13 of Set 10 | oskemen
# Processing Record 14 of Set 10 | mandera
# Processing Record 15 of Set 10 | provo
# Processing Record 16 of Set 10 | lasem
# Processing Record 17 of Set 10 | pahrump
# Processing Record 18 of Set 10 | mullaitivu
# City not found. Skipping
# Processing Record 19 of Set 10 | soroca
# Processing Record 20 of Set 10 | yaan
# Processing Record 21 of Set 10 | armidale
# Processing Record 22 of Set 10 | kadykchan
# City not found. Skipping
# Processing Record 23 of Set 10 | hamilton
# Processing Record 24 of Set 10 | quatre cocos
# Processing Record 25 of Set 10 | korla
# Processing Record 26 of Set 10 | watertown
# Processing Record 27 of Set 10 | villa union
# Processing Record 28 of Set 10 | nishihara
# Processing Record 29 of Set 10 | ilulissat
# Processing Record 30 of Set 10 | constitucion
# Processing Record 31 of Set 10 | kalmunai
# Processing Record 32 of Set 10 | birao
# Processing Record 33 of Set 10 | pierre
# Processing Record 34 of Set 10 | cilegon
# Processing Record 35 of Set 10 | westport
# Processing Record 36 of Set 10 | iquique
# Processing Record 37 of Set 10 | aklavik
# Processing Record 38 of Set 10 | codrington
# Processing Record 39 of Set 10 | hendek
# Processing Record 40 of Set 10 | neiafu
# Processing Record 41 of Set 10 | fougamou
# Processing Record 42 of Set 10 | lac du bonnet
# Processing Record 43 of Set 10 | san luis
# Processing Record 44 of Set 10 | san cristobal
# Processing Record 45 of Set 10 | altagracia de orituco
# Processing Record 46 of Set 10 | sturgis
# Processing Record 47 of Set 10 | sambava
# Processing Record 48 of Set 10 | ereymentau
# Processing Record 49 of Set 10 | rudbar
# Processing Record 50 of Set 10 | vaitape
# Processing Record 1 of Set 11 | galveston
# Processing Record 2 of Set 11 | kudahuvadhoo
# Processing Record 3 of Set 11 | villa oliva
# City not found. Skipping
# Processing Record 4 of Set 11 | azare
# Processing Record 5 of Set 11 | wanning
# Processing Record 6 of Set 11 | semey
# Processing Record 7 of Set 11 | pangody
# Processing Record 8 of Set 11 | tumannyy
# City not found. Skipping
# Processing Record 9 of Set 11 | progreso
# Processing Record 10 of Set 11 | nouadhibou
# Processing Record 11 of Set 11 | olga
# Processing Record 12 of Set 11 | tocopilla
# Processing Record 13 of Set 11 | aswan
# Processing Record 14 of Set 11 | laguna de perlas
# Processing Record 15 of Set 11 | jucas
# Processing Record 16 of Set 11 | anadyr
# Processing Record 17 of Set 11 | alamos
# Processing Record 18 of Set 11 | beringovskiy
# Processing Record 19 of Set 11 | ondorhaan
# City not found. Skipping
# Processing Record 20 of Set 11 | madera
# Processing Record 21 of Set 11 | ati
# Processing Record 22 of Set 11 | cassia
# Processing Record 23 of Set 11 | dzhebariki-khaya
# Processing Record 24 of Set 11 | achisay
# City not found. Skipping
# Processing Record 25 of Set 11 | kamenka
# Processing Record 26 of Set 11 | nha trang
# Processing Record 27 of Set 11 | jacqueville
# Processing Record 28 of Set 11 | coolum beach
# Processing Record 29 of Set 11 | bikaner
# Processing Record 30 of Set 11 | kutum
# Processing Record 31 of Set 11 | rajapur
# Processing Record 32 of Set 11 | camacha
# Processing Record 33 of Set 11 | abu zabad
# Processing Record 34 of Set 11 | dezhou
# Processing Record 35 of Set 11 | palimbang
# Processing Record 36 of Set 11 | jacmel
# Processing Record 37 of Set 11 | chernyshevskiy
# Processing Record 38 of Set 11 | porto walter
# Processing Record 39 of Set 11 | deputatskiy
# Processing Record 40 of Set 11 | dongsheng
# Processing Record 41 of Set 11 | ipixuna
# Processing Record 42 of Set 11 | porto nacional
# Processing Record 43 of Set 11 | kasongo-lunda
# Processing Record 44 of Set 11 | cockburn town
# Processing Record 45 of Set 11 | pemangkat
# Processing Record 46 of Set 11 | ituacu
# Processing Record 47 of Set 11 | ixtapa
# Processing Record 48 of Set 11 | moranbah
# Processing Record 49 of Set 11 | colares
# Processing Record 50 of Set 11 | marzuq
# Processing Record 1 of Set 12 | maneadero
# Processing Record 2 of Set 12 | svetlyy
# Processing Record 3 of Set 12 | talara
# Processing Record 4 of Set 12 | laguna
# Processing Record 5 of Set 12 | san carlos del zulia
# Processing Record 6 of Set 12 | svetlaya
# Processing Record 7 of Set 12 | pacific grove
# Processing Record 8 of Set 12 | vanimo
# Processing Record 9 of Set 12 | carutapera
# Processing Record 10 of Set 12 | biritiba-mirim
# Processing Record 11 of Set 12 | samarai
# Processing Record 12 of Set 12 | camopi
# Processing Record 13 of Set 12 | nipawin
# Processing Record 14 of Set 12 | tatawin
# Processing Record 15 of Set 12 | jyvaskyla
# Processing Record 16 of Set 12 | plouzane
# Processing Record 17 of Set 12 | tibiri
# Processing Record 18 of Set 12 | roma
# Processing Record 19 of Set 12 | omutninsk
# Processing Record 20 of Set 12 | limon
# Processing Record 21 of Set 12 | simao
# Processing Record 22 of Set 12 | haines junction
# Processing Record 23 of Set 12 | shu
# Processing Record 24 of Set 12 | porbandar
# Processing Record 25 of Set 12 | along
# Processing Record 26 of Set 12 | rawson
# Processing Record 27 of Set 12 | tashla
# Processing Record 28 of Set 12 | tongchuan
# Processing Record 29 of Set 12 | tessalit
# Processing Record 30 of Set 12 | la ronge
# Processing Record 31 of Set 12 | san quintin
# Processing Record 32 of Set 12 | sokolo
# Processing Record 33 of Set 12 | aksarayskiy
# Processing Record 34 of Set 12 | north auburn
# Processing Record 35 of Set 12 | warqla
# City not found. Skipping
# Processing Record 36 of Set 12 | cagli
# Processing Record 37 of Set 12 | grand-santi
# Processing Record 38 of Set 12 | fort nelson
# Processing Record 39 of Set 12 | panjab
# Processing Record 40 of Set 12 | tilichiki
# Processing Record 41 of Set 12 | fare
# Processing Record 42 of Set 12 | beian
# Processing Record 43 of Set 12 | sampit
# Processing Record 44 of Set 12 | port lincoln
# Processing Record 45 of Set 12 | castelo branco
# Processing Record 46 of Set 12 | fevralsk
# City not found. Skipping
# Processing Record 47 of Set 12 | bonthe
# Processing Record 48 of Set 12 | toma
# Processing Record 49 of Set 12 | ponta delgada
# Processing Record 50 of Set 12 | kununurra
# Processing Record 1 of Set 13 | quelimane
# Processing Record 2 of Set 13 | rincon
# Processing Record 3 of Set 13 | sao sebastiao
# Processing Record 4 of Set 13 | vestmanna
# Processing Record 5 of Set 13 | tome-acu
# City not found. Skipping
# Processing Record 6 of Set 13 | kamaishi
# Processing Record 7 of Set 13 | haimen
# Processing Record 8 of Set 13 | yuzhno-kurilsk
# Processing Record 9 of Set 13 | paita
# Processing Record 10 of Set 13 | sorland
# Processing Record 11 of Set 13 | la palma
# Processing Record 12 of Set 13 | niquelandia
# Processing Record 13 of Set 13 | lolua
# City not found. Skipping
# Processing Record 14 of Set 13 | kantunilkin
# Processing Record 15 of Set 13 | worland
# Processing Record 16 of Set 13 | contamana
# Processing Record 17 of Set 13 | ulaanbaatar
# Processing Record 18 of Set 13 | kautokeino
# Processing Record 19 of Set 13 | maltahohe
# Processing Record 20 of Set 13 | ponta pora
# Processing Record 21 of Set 13 | kerrobert
# Processing Record 22 of Set 13 | ust-kan
# Processing Record 23 of Set 13 | yashkul
# Processing Record 24 of Set 13 | san ramon
# Processing Record 25 of Set 13 | lebanon
# Processing Record 26 of Set 13 | northam
# Processing Record 27 of Set 13 | burica
# City not found. Skipping
# Processing Record 28 of Set 13 | cayenne
# Processing Record 29 of Set 13 | seminole
# Processing Record 30 of Set 13 | ust-ishim
# Processing Record 31 of Set 13 | challans
# Processing Record 32 of Set 13 | huarmey
# Processing Record 33 of Set 13 | coquimbo
# Processing Record 34 of Set 13 | haldaur
# Processing Record 35 of Set 13 | pangnirtung
# Processing Record 36 of Set 13 | sonoita
# Processing Record 37 of Set 13 | takaka
# Processing Record 38 of Set 13 | ayan
# Processing Record 39 of Set 13 | cavalcante
# Processing Record 40 of Set 13 | tornio
# Processing Record 41 of Set 13 | varhaug
# Processing Record 42 of Set 13 | sorvag
# City not found. Skipping
# Processing Record 43 of Set 13 | vakhrushi
# Processing Record 44 of Set 13 | pointe michel
# Processing Record 45 of Set 13 | taoudenni
# Processing Record 46 of Set 13 | nelson bay
# Processing Record 47 of Set 13 | half moon bay
# Processing Record 48 of Set 13 | yumen
# Processing Record 49 of Set 13 | road town
# Processing Record 50 of Set 13 | yunyang
# Processing Record 1 of Set 14 | zyryanka
# Processing Record 2 of Set 14 | luena
# Processing Record 3 of Set 14 | semporna
# Processing Record 4 of Set 14 | mulchen
# Processing Record 5 of Set 14 | khajuraho
# Processing Record 6 of Set 14 | dzerzhinsk
# Processing Record 7 of Set 14 | vao
# Processing Record 8 of Set 14 | sibu
# Processing Record 9 of Set 14 | oistins
# Processing Record 10 of Set 14 | barbar
# City not found. Skipping
# Processing Record 11 of Set 14 | whitecourt
# Processing Record 12 of Set 14 | grand river south east
# City not found. Skipping
# Processing Record 13 of Set 14 | raudeberg
# Processing Record 14 of Set 14 | hirtshals
# Processing Record 15 of Set 14 | chemax
# Processing Record 16 of Set 14 | ciuhoiu
# Processing Record 17 of Set 14 | kodar
# Processing Record 18 of Set 14 | sistranda
# Processing Record 19 of Set 14 | longavi
# Processing Record 20 of Set 14 | mokhsogollokh
# Processing Record 21 of Set 14 | orlik
# Processing Record 22 of Set 14 | singaraja
# Processing Record 23 of Set 14 | tutoia
# Processing Record 24 of Set 14 | port-gentil
# Processing Record 25 of Set 14 | general roca
# Processing Record 26 of Set 14 | sataua
# City not found. Skipping
# Processing Record 27 of Set 14 | sumbe
# Processing Record 28 of Set 14 | guymon
# Processing Record 29 of Set 14 | monrovia
# Processing Record 30 of Set 14 | puerto cabezas
# Processing Record 31 of Set 14 | lensk
# Processing Record 32 of Set 14 | la baule-escoublac
# Processing Record 33 of Set 14 | padilla
# Processing Record 34 of Set 14 | antofagasta
# Processing Record 35 of Set 14 | fonte boa
# Processing Record 36 of Set 14 | puerto del rosario
# Processing Record 37 of Set 14 | kemijarvi
# Processing Record 38 of Set 14 | yerbogachen
# Processing Record 39 of Set 14 | guilin
# Processing Record 40 of Set 14 | linxia
# Processing Record 41 of Set 14 | kumluca
# Processing Record 42 of Set 14 | karpogory
# Processing Record 43 of Set 14 | lamar
# Processing Record 44 of Set 14 | lapithos
# Processing Record 45 of Set 14 | belmonte
# Processing Record 46 of Set 14 | cocorit
# Processing Record 47 of Set 14 | mujiayingzi
# Processing Record 48 of Set 14 | tsihombe
# City not found. Skipping
# Processing Record 49 of Set 14 | poya
# Processing Record 50 of Set 14 | teguise
# Processing Record 1 of Set 15 | tondano
# Processing Record 2 of Set 15 | japura
# Processing Record 3 of Set 15 | rancho palos verdes
# Processing Record 4 of Set 15 | marv dasht
# City not found. Skipping
# Processing Record 5 of Set 15 | phan rang
# City not found. Skipping
# Processing Record 6 of Set 15 | sisimiut
# Processing Record 7 of Set 15 | aljezur
# Processing Record 8 of Set 15 | najran
# Processing Record 9 of Set 15 | yatou
# Processing Record 10 of Set 15 | ust-tsilma
# Processing Record 11 of Set 15 | pospelikha
# Processing Record 12 of Set 15 | challapata
# Processing Record 13 of Set 15 | chipinge
# Processing Record 14 of Set 15 | robertsganj
# Processing Record 15 of Set 15 | kortkeros
# Processing Record 16 of Set 15 | uruguaiana
# Processing Record 17 of Set 15 | zion
# Processing Record 18 of Set 15 | whitehorse
# Processing Record 19 of Set 15 | morehead
# Processing Record 20 of Set 15 | morgan city
# Processing Record 21 of Set 15 | qaqortoq
# Processing Record 22 of Set 15 | elizabeth city
# Processing Record 23 of Set 15 | nioro
# Processing Record 24 of Set 15 | blackwater
# Processing Record 25 of Set 15 | nizhniy odes
# Processing Record 26 of Set 15 | canutama
# Processing Record 27 of Set 15 | oytal
# Processing Record 28 of Set 15 | butka
# Processing Record 29 of Set 15 | shunyi
# Processing Record 30 of Set 15 | nanakuli
# Processing Record 31 of Set 15 | bafoulabe
# Processing Record 32 of Set 15 | palkaka
# City not found. Skipping
# Processing Record 33 of Set 15 | santa cruz
# Processing Record 34 of Set 15 | parrita
# Processing Record 35 of Set 15 | ashland
# Processing Record 36 of Set 15 | chapais
# Processing Record 37 of Set 15 | tiznit
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 678

# %%
# Add the data to a list in a dict then at the DF
city_data = pd.DataFrame(city_data)
city_data.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tuktoyaktuk      CA  69.4541 -133.0374     21.20        79          90
# 1     Hermanus      ZA -34.4187   19.2345     56.89        72          72
# 2       Burnie      AU -41.0667  145.9167     60.49        48           8
# 3      Rikitea      PF -23.1203 -134.9692     74.97        78         100
# 4         Chuy      UY -33.6971  -53.4616     53.76        83          10
# 5        Tokur      RU  53.1333  132.9000     14.38        58           7
# 6      Ushuaia      AR -54.8000  -68.3000     34.90        91          37
# 7     Necochea      AR -38.5473  -58.7368     54.03        89          66
# 8     Skjervoy      NO  70.0311   20.9714     35.49        82         100
# 9    Carnarvon      AU -24.8667  113.6333     68.40        63          79
#
#    Wind Speed Current Description
# 0       11.50          light snow
# 1        4.70       broken clouds
# 2       10.45           clear sky
# 3       13.85       moderate rain
# 4        2.77           clear sky
# 5        2.48           clear sky
# 6        4.38    scattered clouds
# 7       11.61       broken clouds
# 8       17.07     overcast clouds
# 9       14.56       broken clouds

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_Database.csv"
# Export CSV file 
city_data.to_csv(csv_weather_file, index_label="City_ID")
